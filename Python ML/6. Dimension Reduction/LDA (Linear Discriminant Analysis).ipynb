# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = load_iris()
iris_scaled = StandardScaler().fit_transform(iris.data)
lda = LinearDiscriminantAnalysis(n_components=2)
lda.fit(iris_scaled, iris.target) # LDA는 지도학습이라 training시 label값 필요함
iris_lda = lda.transform(iris_scaled)
print(iris_lda.shape)
# Out:
# (150, 2)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lda_col = ['lda_comp1', 'lda_comp2']
iris_lda_df = pd.DataFrame(iris_lda, columns=lda_col)
iris_lda_df['target'] = iris.target

markers=['^','s','o']

for i, marker in enumerate(markers):
    x_axis_data = iris_lda_df[iris_lda_df['target']==i]['lda_comp1']
    y_axis_data = iris_lda_df[iris_lda_df['target']==i]['lda_comp2']
    
    plt.scatter(x_axis_data, y_axis_data, marker=marker, label=iris.target_names[i])
    
plt.legend(loc='upper left')
plt.xlabel('comp1')
plt.ylabel('comp2')
plt.show()
